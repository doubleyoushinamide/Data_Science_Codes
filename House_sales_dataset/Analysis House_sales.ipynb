# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib

# %%
hsal = pd.read_csv('sale_Dataset.csv')

# %%
hsal.head(5)
# Out:
#    Unnamed: 0       Price          Pid  \
# 0           0     2500000        E9857
# 1           1    30000000     17,H2630
# 2           2  3500000000  10,18,H4485
# 3           3   340000000        H4413
# 4           4    28000000        G8554
#
#                                        Property_name  \
# 0  Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...
# 1  667.0 square meter Land for sale opebi street ...
# 2  3 bedroom House for sale Victoria Island Exten...
# 3  5 bedroom Duplex for sale Lekki Phase 1 Lekki ...
# 4  3 bedroom Flat / Apartment for sale Igando Iko...
#
#                                              Address Neighboorhood
# 0  Eleranigbe Eleranigbe Eleranigbe Ibeju-Lekki L...   Ibeju-Lekki
# 1        Opebi street opebi street Opebi Ikeja Lagos         Ikeja
# 2                     VI Lagos VI Extension VI Lagos            VI
# 3          off afrika lane Lekki Phase 1 Lekki Lagos         Lekki
# 4      NEAR IGANDO B/STOP Igando Ikotun Igando Lagos        Igando

# %%
hsal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9784 entries, 0 to 9783
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     9784 non-null   int64
#  1   Price          9784 non-null   int64
#  2   Pid            9784 non-null   object
#  3   Property_name  9784 non-null   object
#  4   Address        9784 non-null   object
#  5   Neighboorhood  9784 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 458.8+ KB

# %%
#Average Price
hsal['Price'].mean()
# Out:
# 646066931.2893499

# %%
#Maximum price of house sale
hsal['Price'].max()
# Out:
# 1600000000000

# %%
#Alternative means
hsal.loc[hsal['Price'].argmax()]
# Out:
# Unnamed: 0                                                    8071
# Price                                                1600000000000
# Pid                                                          E8516
# Property_name    10 bedroom Commercial Property for sale opebi ...
# Address                              Opebi opebi Opebi Ikeja Lagos
# Neighboorhood                                                Ikeja
# Name: 8071, dtype: object

# %%
#Neighbourhoods with Lekki
len(hsal.loc[hsal['Neighboorhood'] == 'Lekki'])
# Out:
# 2543

# %%
#Neighbourhoods with Ikeja
len(hsal.loc[hsal['Neighboorhood'] == 'Ikeja'])
# Out:
# 661

# %%
#Neighbourhoods with Victoria Island
len(hsal.loc[hsal['Neighboorhood'] == 'VI'])
# Out:
# 314

# %%
hsal.loc[hsal['Price'].argmin()]
# Out:
# Unnamed: 0                                                    1824
# Price                                                         1000
# Pid                                                          H0750
# Property_name    200.0 square meter Land for sale Agbowa Ikorod...
# Address          Agbowa ikosi, ikorodu Agbowa Ikorodu Ikorodu L...
# Neighboorhood                                              Ikorodu
# Name: 1824, dtype: object

# %%
hsal[hsal['Price'] == hsal['Price'].min()]
# Out:
#       Unnamed: 0  Price    Pid  \
# 1824        1824   1000  H0750
# 5540        5540   1000  F7911
#
#                                           Property_name  \
# 1824  200.0 square meter Land for sale Agbowa Ikorod...
# 5540  1.0 square meter Land for sale Agbowa Ikorodu ...
#
#                                                 Address Neighboorhood
# 1824  Agbowa ikosi, ikorodu Agbowa Ikorodu Ikorodu L...       Ikorodu
# 5540  Off Ikorodu-Epe Expressway, by LCDA office Agb...       Ikorodu

# %%
# Mean price by neighboorhood
#We sort_values to sort the int() in increasing order
new = hsal.groupby('Neighboorhood').mean()['Price']
# Out:
# /tmp/ipykernel_3596/3896773744.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new = hsal.groupby('Neighboorhood').mean()['Price']

# %%
hsal.groupby('Neighboorhood').mean()['Price']
# Out:
# /tmp/ipykernel_3596/387853239.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hsal.groupby('Neighboorhood').mean()['Price']
# Neighboorhood
# Abule-Egba      7.935632e+08
# Agege           6.556522e+07
# Ajah            1.088547e+08
# Alapere         3.880905e+07
# Alimosho        4.712088e+07
# Amuwo-Odofin    1.118605e+09
# Apapa           2.630346e+10
# Badagry         5.248033e+08
# Bariga          4.268611e+07
# Ejigbo          3.264706e+07
# Epe             2.144881e+07
# Gbagada         5.419821e+07
# Ibeju-Lekki     1.053292e+08
# Idimu           6.255938e+07
# Ifako-Ijaiye    3.500000e+07
# Igando          4.816434e+07
# Ijora           7.500000e+07
# Ikeja           2.800974e+09
# Ikorodu         7.039645e+07
# Ikosi           3.705000e+08
# Ikoyi           8.674291e+08
# ...

# %%
hsal['new_col'] = new

# %%
# Drop columns with NA axis = 1 for col. and 0 for index
hsal = hsal.dropna(axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
hsal.head()
# Out:
#    Unnamed: 0       Price          Pid  \
# 0           0     2500000        E9857
# 1           1    30000000     17,H2630
# 2           2  3500000000  10,18,H4485
# 3           3   340000000        H4413
# 4           4    28000000        G8554
#
#                                        Property_name  \
# 0  Land for sale Eleranigbe Eleranigbe Ibeju-Lekk...
# 1  667.0 square meter Land for sale opebi street ...
# 2  3 bedroom House for sale Victoria Island Exten...
# 3  5 bedroom Duplex for sale Lekki Phase 1 Lekki ...
# 4  3 bedroom Flat / Apartment for sale Igando Iko...
#
#                                              Address Neighboorhood
# 0  Eleranigbe Eleranigbe Eleranigbe Ibeju-Lekki L...   Ibeju-Lekki
# 1        Opebi street opebi street Opebi Ikeja Lagos         Ikeja
# 2                     VI Lagos VI Extension VI Lagos            VI
# 3          off afrika lane Lekki Phase 1 Lekki Lagos         Lekki
# 4      NEAR IGANDO B/STOP Igando Ikotun Igando Lagos        Igando

# %%
plt.style.use('classic')
plt.rcParams['font.family'] = 'Garamond'
plt.figure(figsize=(10, 15))
d
ab = sns.barplot(x='Price', y='Neighboorhood', data=hsal, width=0.9, errorbar='se', capsize=0.3)
ab.set(xlabel = 'House Price (10 Billions)', mouseover=True)
ab.set(ylabel = 'Neighbourhood', mouseover=True)

plt.savefig('House_price.svg')

# %%
plt.savefig('House_price.svg')

# %%
hsal.head(50)
# Out:
#     Unnamed: 0        Price          Pid  \
# 0            0      2500000        E9857
# 1            1     30000000     17,H2630
# 2            2   3500000000  10,18,H4485
# 3            3    340000000        H4413
# 4            4     28000000        G8554
# 5            5     13000000        G5150
# 6            6     12000000        G4891
# 7            7     10000000        G4886
# 8            8    450000000        H2245
# 9            9     30000000        H0634
# 10          10      7000000        H0652
# 11          11    180000000        H3290
# 12          12    160000000        H4181
# 13          13     20000000     20,H5794
# 14          14      2500000        H1579
# 15          15     60000000        G4612
# 16          16      5000000        H1058
# 17          17     60000000        G3849
# 18          18      4000000        H4686
# 19          19     30000000        G5330
# 20          20     25000000        G6335
# 21          21     50000000        H5031
# ...

# %%
# Sorting of neighboorhood column by freq.
hsal['Neighboorhood'].value_counts().head(50)
# Out:
# Lekki           2543
# Ibeju-Lekki      872
# Ajah             690
# Ikeja            661
# Ikoyi            599
# Ojo              394
# Ikorodu          359
# Sangotedo        355
# VI               314
# Kosofe           292
# Yaba             256
# Ipaja            231
# Surulere         226
# Ogba             199
# Amuwo-Odofin     199
# Gbagada          168
# Maryland         145
# Okota            132
# Igando           129
# Ogudu            124
# Isolo            123
# Agege             92
# Abule-Egba        91
# Alimosho          91
# Alapere           63
# Apapa             60
# Oshodi            52
# Badagry           45
# Epe               42
# Shomolu           39
# Idimu             32
# VGC               30
# Lagos-Island      26
# Ilupeju           23
# Ikosi             22
# Bariga            18
# Ejigbo            17
# Mushin            17
# Orile             10
# Ijora              2
# Ifako-Ijaiye       1
# Name: Neighboorhood, dtype: int64

# %%
hsal[hsal['Neighboorhood'] == 'VI'].sort_index().count()
# Out:
# Unnamed: 0       314
# Price            314
# Pid              314
# Property_name    314
# Address          314
# Neighboorhood    314
# dtype: int64

# %%
hsal[hsal['Neighboorhood'] == 'VI'].sort_index()
# Out:
#       Unnamed: 0       Price          Pid  \
# 2              2  3500000000  10,18,H4485
# 44            44   500000000        H5712
# 48            48  3500000000        H5704
# 49            49   400000000        H5703
# 50            50  1000000000        H5700
# ...          ...         ...          ...
# 9634        9634   180000000        E1709
# 9657        9657    70000000        E1545
# 9691        9691    60000000        E1335
# 9771        9771   450000000        E0747
# 9782        9782   450000000        E0719
#
#                                           Property_name  \
# 2     3 bedroom House for sale Victoria Island Exten...
# 44    Land for sale Ligali Ayorinde Victoria Island ...
# 48    Land for sale Ligali Ayorinde Victoria Island ...
# 49    Land for sale Ligali Ayorinde Victoria Island ...
# 50     Land for sale Adeola Odeku Victoria Island Lagos
# ...                                                 ...
# 9634  6 bedroom Duplex for sale Victoria Island Exte...
# ...
